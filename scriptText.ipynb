-- %% [markdown]
-- # [Fitness]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Fitness]    Script Date: 19/10/2025 10:49:15 CH ******/
CREATE DATABASE [Fitness]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Fitness', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.DBMS_ZUZU\MSSQL\DATA\Fitness.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Fitness_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.DBMS_ZUZU\MSSQL\DATA\Fitness_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Fitness] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Fitness].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Fitness] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Fitness] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Fitness] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Fitness] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Fitness] SET ARITHABORT OFF 
GO
ALTER DATABASE [Fitness] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Fitness] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Fitness] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Fitness] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Fitness] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Fitness] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Fitness] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Fitness] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Fitness] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Fitness] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Fitness] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Fitness] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Fitness] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Fitness] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Fitness] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Fitness] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Fitness] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Fitness] SET RECOVERY FULL 
GO
ALTER DATABASE [Fitness] SET  MULTI_USER 
GO
ALTER DATABASE [Fitness] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Fitness] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Fitness] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Fitness] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Fitness] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Fitness] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'Fitness', N'ON'
GO
ALTER DATABASE [Fitness] SET QUERY_STORE = ON
GO
ALTER DATABASE [Fitness] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[activity]

-- %%
USE [Fitness]
GO

-- %%
/****** Object:  Table [dbo].[activity]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[activity](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[met_value] [float] NULL,
	[name] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[activity_log]

-- %%
/****** Object:  Table [dbo].[activity_log]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[activity_log](
	[logid] [int] IDENTITY(1,1) NOT NULL,
	[date_log] [datetime2](6) NULL,
	[duration] [float] NULL,
	[activity_id] [int] NULL,
	[user_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[logid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[blog]

-- %%
/****** Object:  Table [dbo].[blog]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[blog](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[approved] [bit] NULL,
	[content] [varchar](255) NULL,
	[date_created] [datetime2](6) NULL,
	[title] [varchar](255) NULL,
	[user_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[diet]

-- %%
/****** Object:  Table [dbo].[diet]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[diet](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[carb_percent] [int] NULL,
	[fat_percent] [int] NULL,
	[name] [varchar](255) NULL,
	[protein_percent] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[dish]

-- %%
/****** Object:  Table [dbo].[dish]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[dish](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[calories] [float] NULL,
	[carb] [float] NULL,
	[des] [varchar](255) NULL,
	[fat] [float] NULL,
	[fiber] [float] NULL,
	[food_picture] [varchar](255) NULL,
	[name] [varchar](255) NULL,
	[protein] [float] NULL,
	[unit] [smallint] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[food_log]

-- %%
/****** Object:  Table [dbo].[food_log]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[food_log](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[log_time] [datetime2](6) NULL,
	[meal] [smallint] NULL,
	[user_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[meal_detail]

-- %%
/****** Object:  Table [dbo].[meal_detail]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[meal_detail](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[food_intake] [float] NULL,
	[dish_id] [int] NULL,
	[food_log_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[role]

-- %%
/****** Object:  Table [dbo].[role]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[role](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[training_mode]

-- %%
/****** Object:  Table [dbo].[training_mode]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[training_mode](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[des] [varchar](255) NULL,
	[duration] [int] NULL,
	[name] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[user_diet]

-- %%
/****** Object:  Table [dbo].[user_diet]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[user_diet](
	[carb_percent] [int] NULL,
	[fat_percent] [int] NULL,
	[protein_percent] [int] NULL,
	[diet_id] [int] NOT NULL,
	[user_id] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[diet_id] ASC,
	[user_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[user_workout]

-- %%
/****** Object:  Table [dbo].[user_workout]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[user_workout](
	[user_id] [int] NOT NULL,
	[work_id] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[users]

-- %%
/****** Object:  Table [dbo].[users]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[users](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[age] [float] NULL,
	[bmi] [float] NULL,
	[bmr] [float] NULL,
	[email] [varchar](255) NULL,
	[gender] [varchar](255) NULL,
	[goal] [float] NULL,
	[height] [float] NULL,
	[level_activity] [float] NULL,
	[name] [varchar](255) NULL,
	[password] [varchar](255) NULL,
	[phone_number] [bigint] NULL,
	[tdee] [float] NULL,
	[weight] [float] NULL,
	[role_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[workout]

-- %%
/****** Object:  Table [dbo].[workout]    Script Date: 19/10/2025 10:49:16 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[workout](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[calories_burned] [float] NULL,
	[duration] [float] NULL,
	[link_video] [varchar](255) NULL,
	[name] [varchar](255) NULL,
	[training_mode_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK634sb3dvk7nyxjcjcem7m282a]

-- %%
ALTER TABLE [dbo].[activity_log]  WITH CHECK ADD  CONSTRAINT [FK634sb3dvk7nyxjcjcem7m282a] FOREIGN KEY([user_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[activity_log] CHECK CONSTRAINT [FK634sb3dvk7nyxjcjcem7m282a]
GO

-- %% [markdown]
-- # [FKadd6g0gp5xkonquavbrmowk7c]

-- %%
ALTER TABLE [dbo].[activity_log]  WITH CHECK ADD  CONSTRAINT [FKadd6g0gp5xkonquavbrmowk7c] FOREIGN KEY([activity_id])
REFERENCES [dbo].[activity] ([id])
GO
ALTER TABLE [dbo].[activity_log] CHECK CONSTRAINT [FKadd6g0gp5xkonquavbrmowk7c]
GO

-- %% [markdown]
-- # [FKkr2fy24puc3x3sdnla4r1iok1]

-- %%
ALTER TABLE [dbo].[blog]  WITH CHECK ADD  CONSTRAINT [FKkr2fy24puc3x3sdnla4r1iok1] FOREIGN KEY([user_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[blog] CHECK CONSTRAINT [FKkr2fy24puc3x3sdnla4r1iok1]
GO

-- %% [markdown]
-- # [FKm0ff2td1vmwthjqe6p2ldydkt]

-- %%
ALTER TABLE [dbo].[food_log]  WITH CHECK ADD  CONSTRAINT [FKm0ff2td1vmwthjqe6p2ldydkt] FOREIGN KEY([user_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[food_log] CHECK CONSTRAINT [FKm0ff2td1vmwthjqe6p2ldydkt]
GO

-- %% [markdown]
-- # [FK5th6yskal6nbsfhovyqh636s7]

-- %%
ALTER TABLE [dbo].[meal_detail]  WITH CHECK ADD  CONSTRAINT [FK5th6yskal6nbsfhovyqh636s7] FOREIGN KEY([food_log_id])
REFERENCES [dbo].[food_log] ([id])
GO
ALTER TABLE [dbo].[meal_detail] CHECK CONSTRAINT [FK5th6yskal6nbsfhovyqh636s7]
GO

-- %% [markdown]
-- # [FKbdgf7v89qvchltxkar7xffcua]

-- %%
ALTER TABLE [dbo].[meal_detail]  WITH CHECK ADD  CONSTRAINT [FKbdgf7v89qvchltxkar7xffcua] FOREIGN KEY([dish_id])
REFERENCES [dbo].[dish] ([id])
GO
ALTER TABLE [dbo].[meal_detail] CHECK CONSTRAINT [FKbdgf7v89qvchltxkar7xffcua]
GO

-- %% [markdown]
-- # [FK560pdubduwrelx4530mxcnjq9]

-- %%
ALTER TABLE [dbo].[user_diet]  WITH CHECK ADD  CONSTRAINT [FK560pdubduwrelx4530mxcnjq9] FOREIGN KEY([user_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[user_diet] CHECK CONSTRAINT [FK560pdubduwrelx4530mxcnjq9]
GO

-- %% [markdown]
-- # [FKrdxp6wbdbxbuk1np67iq2fjlo]

-- %%
ALTER TABLE [dbo].[user_diet]  WITH CHECK ADD  CONSTRAINT [FKrdxp6wbdbxbuk1np67iq2fjlo] FOREIGN KEY([diet_id])
REFERENCES [dbo].[diet] ([id])
GO
ALTER TABLE [dbo].[user_diet] CHECK CONSTRAINT [FKrdxp6wbdbxbuk1np67iq2fjlo]
GO

-- %% [markdown]
-- # [FKdtpk4f8xe1dbf40bq3gkmageb]

-- %%
ALTER TABLE [dbo].[user_workout]  WITH CHECK ADD  CONSTRAINT [FKdtpk4f8xe1dbf40bq3gkmageb] FOREIGN KEY([user_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[user_workout] CHECK CONSTRAINT [FKdtpk4f8xe1dbf40bq3gkmageb]
GO

-- %% [markdown]
-- # [FKfp9s80jn6fhake987uwi3vb30]

-- %%
ALTER TABLE [dbo].[user_workout]  WITH CHECK ADD  CONSTRAINT [FKfp9s80jn6fhake987uwi3vb30] FOREIGN KEY([work_id])
REFERENCES [dbo].[workout] ([id])
GO
ALTER TABLE [dbo].[user_workout] CHECK CONSTRAINT [FKfp9s80jn6fhake987uwi3vb30]
GO

-- %% [markdown]
-- # [FK4qu1gr772nnf6ve5af002rwya]

-- %%
ALTER TABLE [dbo].[users]  WITH CHECK ADD  CONSTRAINT [FK4qu1gr772nnf6ve5af002rwya] FOREIGN KEY([role_id])
REFERENCES [dbo].[role] ([id])
GO
ALTER TABLE [dbo].[users] CHECK CONSTRAINT [FK4qu1gr772nnf6ve5af002rwya]
GO

-- %% [markdown]
-- # [FK4jv3kb9w0gqg9l60x4w5w8k18]

-- %%
ALTER TABLE [dbo].[workout]  WITH CHECK ADD  CONSTRAINT [FK4jv3kb9w0gqg9l60x4w5w8k18] FOREIGN KEY([training_mode_id])
REFERENCES [dbo].[training_mode] ([id])
GO
ALTER TABLE [dbo].[workout] CHECK CONSTRAINT [FK4jv3kb9w0gqg9l60x4w5w8k18]
GO

-- %% [markdown]
-- # [CK__dish__unit__3F466844]

-- %%
ALTER TABLE [dbo].[dish]  WITH CHECK ADD CHECK  (([unit]>=(0) AND [unit]<=(1)))
GO

-- %% [markdown]
-- # [CK__food_log__meal__4222D4EF]

-- %%
ALTER TABLE [dbo].[food_log]  WITH CHECK ADD CHECK  (([meal]>=(0) AND [meal]<=(2)))
GO

-- %% [markdown]
-- # [Fitness]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Fitness] SET  READ_WRITE 
GO
